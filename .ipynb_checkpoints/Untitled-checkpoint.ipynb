# %% [markdown]
# # Head

# %% [markdown]
# ## General tips

# %%
#Import packages
import numpy as np

import pandas as pd

import matplotlib as mpl 

import matplotlib.pyplot as plt

# %%
# Setting styles
plt.style.use('classic')

# %%
# plot figures
x = np.linspace(0, 10, 100)
fig = plt.figure() 
plt.plot(x, np.sin(x), '-') 
plt.plot(x, np.cos(x), '--')

# %%
#Save figure
fig.savefig('my_figure.p')

# %%
#Two interface-1
#matlab-style
plt.figure() # create a plot figure
# create the first of two panels and set current axis 
plt.subplot(2, 1, 1) # (rows, columns, panel number) 
plt.plot(x, np.sin(x))
# create the second panel and set current axis 
plt.subplot(2, 1, 2) 
plt.plot(x, np.cos(x))

# %%
#Object-oriented interface
# First create a grid of plots # ax will be an array of two Axes objects 
fig, ax = plt.subplots(2)
# Call plot() method on the appropriate object 
ax[0].plot(x, np.sin(x)) 
ax[1].plot(x, np.cos(x))

# %%
# One more example
fig = plt.figure() 
ax = plt.axes()
x = np.linspace(0, 10, 1000) 
ax.plot(x, np.sin(x))

plt.plot(x, np.cos(x))

# %% [markdown]
# ## Simple line plots

# %%
plt.plot(x, np.sin(x - 0), color='blue')
# specify color by name
plt.plot(x, np.sin(x - 1), color='g')
# short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')
# Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')
# Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1 
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, np.sin(x - 4), color=(0.8,0.5,0.9))

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes: 
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
plt.plot(x, x + 7, linestyle=':',color=(0.8,0.5,0.9))

# %%
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11) 
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))
plt.xlim(10, 0) 
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x, np.sin(x)) 
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %%
plt.plot(x, np.sin(x)) 
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %% [markdown]
# ### Labeling plots

# %%
plt.plot(x, np.sin(x)) 
plt.title("A Sine Curve")
plt.xlabel("x") 
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)') 
plt.plot(x, np.cos(x), ':b', label='cos(x)') 
plt.axis('equal')
plt.legend()

# %% [markdown]
# ### change to the other style
# - plt.xlabel() → ax.set_xlabel()
# - plt.ylabel() → ax.set_ylabel()
# - plt.xlim() → ax.set_xlim()
# - plt.ylim() → ax.set_ylim()
# - plt.title() → ax.set_title()

# %% [markdown]
# ## Scatter plots

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
plt.style.use('seaborn-whitegrid') 
import numpy as np
x = np.linspace(0, 10, 30) 
y = np.sin(x) 
plt.plot(x, y, 'o', color='black')
# The third argument in the function call is a character that represents the type of symbol used for the plotting

# %%
plt.plot(x, y, '-ok'); # line (-), circle marker (o), black (k)

# %%
plt.plot(x, y, '-p', color='gray', markersize=15, linewidth=4, markerfacecolor='white', markeredgecolor='blue', markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ### Scatter Plots with plt.scatter

# %%
plt.scatter(x, y, marker='o')

# %%
rng = np.random.RandomState(0) 
x = rng.randn(100) 
y = rng.randn(100) 
colors = rng.rand(100) 
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar(); # show color scale Figure

# %% [markdown]
# ### error bars

# %%
x = np.linspace(0, 10, 50) 
dy = 0.8 
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Histograms, Binnings, and Density

# %%
# %matplotlib inline 
import numpy as np 
import matplotlib.pyplot as plt 
plt.style.use('seaborn-white')
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([ 11.,  41., 107., 174., 255., 222., 113.,  52.,  20.,   5.]),
#  array([-2.87143667, -2.2456374 , -1.61983812, -0.99403885, -0.36823958,
#          0.2575597 ,  0.88335897,  1.50915824,  2.13495752,  2.76075679,
#          3.38655606]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,density='True')
# Out:
# (array([0.011, 0.052, 0.159, 0.333, 0.588, 0.81 , 0.923, 0.975, 0.995,
#         1.   ]),
#  array([-2.87143667, -2.2456374 , -1.61983812, -0.99403885, -0.36823958,
#          0.2575597 ,  0.88335897,  1.50915824,  2.13495752,  2.76075679,
#          3.38655606]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=30, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none')
# Out:
# (array([ 1.,  1.,  1.,  3.,  3.,  8., 12., 16., 35., 39., 58., 68., 78.,
#         79., 86., 86., 85., 85., 66., 53., 51., 32., 14., 19.,  5., 10.,
#          3.,  2.,  0.,  1.]),
#  array([-3.52259442, -3.29434618, -3.06609793, -2.83784969, -2.60960144,
#         -2.38135319, -2.15310495, -1.9248567 , -1.69660845, -1.46836021,
#         -1.24011196, -1.01186372, -0.78361547, -0.55536722, -0.32711898,
#         -0.09887073,  0.12937752,  0.35762576,  0.58587401,  0.81412225,
#          1.0423705 ,  1.27061875,  1.49886699,  1.72711524,  1.95536349,
#          2.18361173,  2.41185998,  2.64010823,  2.86835647,  3.09660472,
#          3.32485296]),
#  [<matplotlib.patches.Polygon at 0x7f2c617359a0>])

# %%
x1 = np.random.normal(0, 0.8, 1000) 
x2 = np.random.normal(-2, 1, 1000) 
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)
plt.hist(x1, **kwargs) 
plt.hist(x2, **kwargs) 
plt.hist(x3, **kwargs)
# Out:
# (array([ 5.,  0.,  4.,  4.,  5.,  7., 13., 17., 16., 29., 21., 37., 41.,
#         43., 45., 58., 67., 54., 52., 55., 57., 66., 53., 52., 35., 28.,
#         29., 13., 21., 20., 17., 12.,  9.,  5.,  3.,  2.,  2.,  1.,  1.,
#          1.]),
#  array([-2.60493775, -2.30638503, -2.00783232, -1.7092796 , -1.41072688,
#         -1.11217416, -0.81362144, -0.51506873, -0.21651601,  0.08203671,
#          0.38058943,  0.67914215,  0.97769487,  1.27624758,  1.5748003 ,
#          1.87335302,  2.17190574,  2.47045846,  2.76901118,  3.06756389,
#          3.36611661,  3.66466933,  3.96322205,  4.26177477,  4.56032748,
#          4.8588802 ,  5.15743292,  5.45598564,  5.75453836,  6.05309108,
#          6.35164379,  6.65019651,  6.94874923,  7.24730195,  7.54585467,
#          7.84440738,  8.1429601 ,  8.44151282,  8.74006554,  9.03861826,
#          9.33717098]),
#  [<matplotlib.patches.Polygon at 0x7f2c616d7d00>])
